# %% [markdown]
# # import numpy as np
# import pandas as pd

# %%
my_index = ['Physics'] * 3 + ['Engineering Chemistry'] * 3 + ['Object oriented Programming'] * 2 + ['BEEE'] * 2  + ['Calculus'] * 3 + ['Differential Equations'] * 2 + ['Complex and Linear Algebra'] * 2 + ['Discrete and Graph Theory'] * 2

# %%
np.random.seed(40)
random_integers1 = np.random.randint(0, 11, 19)

# %%
np.random.seed(41)
random_integers2 = np.random.randint(0, 11, 19)

# %%
np.random.seed(42)
random_integers3 = np.random.randint(0, 11, 19)

# %%
data_one = {'Teacher Name': ['Parthiban', 'Anuradha C', 'Kaushik Chanda', 'Harshita Patel', 'Rani C', 'Suganya P', 'Kavitha A', 'Akella Venkata Suryanaryan Murthy', 'Venkateshwarlu', 'nanavignesh', 'Parthiban', 'Kaushik Chanda', 'Rani C', 'Harshita Patel', 'Suganya P', 'Kavitha A', 'Akella Venkata Suryanaryan Murthy', 'Venkateshwarlu', 'nanavignesh'],'Teaching': random_integers1,'Marks': random_integers2, 'Supportive': random_integers3}

# %%
df = pd.DataFrame(data = data_one, index = my_index)
df
# Out:
#                                                   Teacher Name  Teaching  \
# Physics                                              Parthiban         6
# Physics                                             Anuradha C         7
# Physics                                         Kaushik Chanda         5
# Engineering Chemistry                           Harshita Patel         8
# Engineering Chemistry                                   Rani C         8
# Engineering Chemistry                                Suganya P         2
# Object oriented Programming                          Kavitha A         1
# Object oriented Programming  Akella Venkata Suryanaryan Murthy         7
# BEEE                                            Venkateshwarlu         2
# BEEE                                               nanavignesh         3
# Calculus                                             Parthiban        10
# Calculus                                        Kaushik Chanda         7
# ...

# %%
teach_marks = df['Teaching'] + df['Marks']
teach_supp = df['Teaching'] + df['Supportive']
marks_supp = df['Marks'] + df['Supportive']
teach_marks_supp = df['Teaching'] + df['Marks'] + df['Supportive']

# %%
df['teach_marks'] = t_m
df['teach_supp'] = teach_supp
df['marks_supp'] = marks_supp
df['teach_marks_supp'] = teach_marks_supp
df
# Out:
#                                                   Teacher Name  Teaching  \
# Physics                                              Parthiban         6
# Physics                                             Anuradha C         7
# Physics                                         Kaushik Chanda         5
# Engineering Chemistry                           Harshita Patel         8
# Engineering Chemistry                                   Rani C         8
# Engineering Chemistry                                Suganya P         2
# Object oriented Programming                          Kavitha A         1
# Object oriented Programming  Akella Venkata Suryanaryan Murthy         7
# BEEE                                            Venkateshwarlu         2
# BEEE                                               nanavignesh         3
# Calculus                                             Parthiban        10
# Calculus                                        Kaushik Chanda         7
# ...
